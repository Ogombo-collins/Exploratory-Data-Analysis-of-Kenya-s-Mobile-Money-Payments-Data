# %% [markdown]
# # Exploratory Data Analysis of Kenya's Mobile Money Payments Data Using Python

# %% [markdown]
# ![Mobile Payments Mpesa](Mobile%20Payments%20Mpesa.jpg)
#
# Source: [Efi Chalikopoulou](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.vox.com%2Ffuture-perfect%2F21420357%2Fkenya-mobile-banking-unbanked-cellphone-money&psig=AOvVaw2SRqr3H-m_3oWk1xXHkgI3&ust=1698495118217000&source=images&cd=vfe&opi=89978449&ved=0CBQQjhxqFwoTCICDxsmZloIDFQAAAAAdAAAAABAh)

# %% [markdown]
# ## Mobile Money Payments
#
# Mobile money payment is a system of paying for goods and services, and sending money to friends and family members using a portable electronic device like PDAs (smartphones and tablets). Mobile money payments services are commonly offered by mobile network providers and third party providers contracted by banks.
#
# Anyone armed with a phone can open a money wallet which will be used to store value (money) that can be exchanged for goods and services.
#
# Majority of mobile money services allow receiving and sending money to peers, as well storing it in a virtual wallet on your mobile device or withdrawing and depositing at licenced agents.
#
# According to a report by **Statista**, mobile wallets such as PayPal, Apple Pay, and Alipay are the most widely used mobile payment methods globally. In Asia-Pacific alone, there are an estimated [2.8 billion mobile wallets](https://www.statista.com/topics/4872/mobile-payments-worldwide/#topicOverview) in use.
#
# **Benefits of Mobile Money Payments**
#
# Some of the benefits of Mobile Money Payments include:
#
# 1. Offer convenient way of sending money and purchasing products.
# 2. Provide a faster way of making payments. Transctions occur in real-time.
# 3. Cost-effectives for merchants who incur costs from Point-of-Sale equipments and reduction in transactions costs for customers who use credit cards.
# 4. Ease of accessibility. Anyone with a mobile phone and prerequisite documents such as national identity card can own a digital wallet.
# 5. Provide a secure way of making payments. Physical cash can easily get lost and customer data is encrypted when they make transactions.

# %% [markdown]
# ## Mobile Money Payments in Kenya
#
# In Kenya, mobile money payments is ubiquitous as beer(_**cold Tusker**_) is to an Kenyan football fanatic. The cradle of mobile payments can be traced to Kenya, when Safaricom (Kenya's leading telecommunications network) gave birth to M-Pesa in 2007.
#
# Back then, the goal of the newborn was facilitate sending of money to friends and family residing in rural areas. The newborn's growth, 15 years later has resulted to:
#
# - More than 604,000 active agents operating across the Democratic Republic of Congo (DRC), Egypt, Ghana, Kenya, Lesotho, Mozambique and Tanzania
# - More [than 51 million customers](https://www.vodafone.com/about-vodafone/what-we-do/consumer-products-and-services/m-pesa) across seven countries in Africa
# - Over $314 billion in transactions per year
#
#
# **Mobile Money Providers in Kenya**
#
# According to the Central Bank of Kenya (CBK), there are 3 major mobile money providers in Kenya:
# - M-PESA
# - Airtel Money
# - T-cash
#
#
# **Features of Mobile Money Payments in Kenya**
#
# Some of the features of mobile money payments in Kenya are:
#
# - **Interoperability**: Mobile money customers can send and receive money across different networks in real time, thanks to the full [interoperability of mobile money services]( https://www.centralbank.go.ke/wp-content/uploads/2023/02/Kenyas-Payments-Journey.pdf) that was announced by the Central Bank of Kenya in September 2022.
# - **International remittances**: Mobile money customers can also send and receive money from abroad through various international remittance partners, such as WorldRemit, Western Union, MoneyGram, and PayPal.
# - **Financial inclusion**: Mobile money has enabled millions of Kenyans who do not have bank accounts or have limited access to banking services to access financial services such as savings, loans, insurance, and investments through their mobile phones.
# - **Government payments**: Mobile money has also facilitated the payment of taxes, fees, fines, and other government services by citizens and businesses through platforms such as KRA iTax, eCitizen, and Huduma Number.
# - **Innovation and growth**: Mobile money has driven innovation and growth in various sectors of the economy, such as agriculture, health, education, and e-commerce, by providing a safe, secure, and affordable way of paying for goods and services.

# %% [markdown]
# # Exploratory Data Analysis
#
# Exploratory data analysis involves investigating and summarizing key insights and main characteristics linked to the data. The process provides answers to significant questions that arise when processing(cleaning) the data.
#
#
#
# **Goals of Exploratory Data Analysis**
#
# Key goals looking to be achieved by implementing EDA include:
#
# - Discovering the underlying structure of the dataset
# - Extract patterns, anomalies and trends in the dataset
# - Test hypotheses and validate assumptions about the data
# - Forecast what problems could be solved by insights extracted from the data
#
# **Benefits of Exploratory Data Analysis**
#
# Conducting EDA helps data scientists,machine learning engineers and data analysts in various ways. The advantages of EDA include:
#
# 1. Acquiring insights into [underlying trends and patterns](https://www.knowledgehut.com/blog/data-science/eda-data-science)
# 2. Increase understanding of data features and how they relate to each other
# 3. Optimize data-driven decisions by improving data understanding
# 4. Deriving better questions that are relevant to our data and business challenge.
#
# The key elements that will be discussed in our EDA of Kenyan Mobile Payments dataset include:
#
# - Dataset Profile
# - Types of Exploratory Data Analysis
# - Exploratory Data Analysis Process

# %% [markdown]
# ## Dataset Profile
#
# **Dataset content**: The dataset shows  monthly data on the number of active agents, registered mobile money accounts, and agent cash in and out transactions in Kenya from January 2007 to August 2023.
#
# **Source of Data**: Data is published by Central Bank of Kenya (CBK), the regulatory authority for mobile payments in Kenya. You can access the data by clicking [here](https://www.centralbank.go.ke/national-payments-system/mobile-payments/). Once you click the link,the data can be exported to Excel or CSV files, copied or converted to PDF files.
#
# **Data Accuracy**: It is collected and published by CBK.
#
# **Data Format**: For this task, the data is in CSV file format.
#
# **Data features**: Columns present in the dataset are year, month, active agents, total registered mobile money accounts, total agent cash in cash out volume and total agent cash in cash out value.
#
# **Data Features Meaning:**
#
# 1. Year: Annual fiscal year mobile money transactions occur in Kenya
# 2. Month: Monthly data for mobile money transactions
# 3. Total registered mobile money accounts: Number of users who have registered mobile money accounts
# 4. Total agent cash in cash out volume: Quantity of mobile money transactions  as per records of mobile money agents. **Mobile money agents** are small mobile phone stores or retail locations—which allow users to deposit and withdraw in-person. Cash in represent deposits and cash out represent cash withdrawals
# 5. Total cash in cash out value: Monetary value of all mobile money transactions that occurred in Kenya from January 2007 to August 2023

# %% [markdown]
# ## Types of Exploratory Data Analysis
#
# Types of Exploratory data analysis can be categorized into two major categories:
#
# - Graphical EDA versus Non-graphical EDA
# - Core Types of EDA based on Graphical and Non-graphical EDA
#
#
# ### Graphical EDA versus Non-graphical EDA
#
# Exploratory data analysis can be done [graphically or non-graphically](https://www.ibm.com/topics/exploratory-data-analysis#:~:text=Exploratory%20data%20analysis%20(EDA)%20is,often%20employing%20data%20visualization%20methods.). One paints a picture behind the numbers while the other does not lie.
#
# a) **Graphical exploratory data analysis:**
#
# Graphical EDA  entails use of graphs to visualize the data and identify patterns that may not be discernible from the raw data.  It helps in displaying the data, describing the distribution of data and relationships between variables present in the dataset.
#
# Some of the common charts/visualizations used in graphical EDA include:
# 1. Histograms
# 2. Line graphs
# 3. Box plots
# 4. Heatmaps
# 5. Scatterplots
# 6. Pie charts
# 7. Bar graphs
# 8. Contingency tables
#
# Developing exploratory visualizations is the cornerstone of graphical EDA.
#
# b) **Non-graphical exploratory data analysis:**
#
# Non-graphical EDA involves [use of statistical techniques ](https://analyticsindiamag.com/exploratory-data-analysis-functions-types-tools/) to explore the data. It involves computing summary statistics such as measures of central tendency (mean, median, mode), measures of dispersion (variance, standard deviation), and correlation coefficients between variables present in a raw dataset.
#
# Patterns and insights that cannot be easily deduced from graphical EDA can be obtained via non-graphical EDA.

# %% [markdown]
# ### Core Types of EDA
#
# The other three core types of Exploratory Data Analysis include:
#
# - Univariate Analysis
# - Bivariate Analysis
# - Multivariate Analysis
#
# 1) **Univariate Analysis:**
#
# Univariate EDA involves analyzing a single variable. It helps one understand the distribution of data of a single variable.
# There is no cause-and-effect analysis where causes or relationships between variables are assessed.
#
# It can be presented **graphically** or **non-graphically**. Univariate graphical entails creating charts and graphs to explore a single variable.
#
# The common types of univariate visuals include:
#
# - Stem-and-leaf plots: Show all data values and the shape of the distribution.
# - Histograms: A bar plot in which each bar represents the frequency (count) or proportion (count/total count) of observations for a range of values.
# - Box plots: Graphically depict the five-number summary of minimum, first quartile, median, third quartile, and maximum.
#
# Univariate non-graphical involves describing the data and finding patterns using statistical methods. It is the simplest form of EDA.
#
# 2) **Bivariate Analysis**
#
# Bivariate EDA entails analyzing two variables. It helps one understand the relationship between two variables. There is a cause and relationship between two variables.
#
# Bivariate EDA can also be executed **graphically and non-graphically** whereby summary statistics that allow you to assess the relationship between each variable in the dataset and the target variable you’re looking at can be developed by the analyst.
#
# 3) **Multivariate Analysis**
#
# Multivariate analysis involves analyzing more than two variables at a time to establish patterns and relationships. The variables can be a mixture of numerical variables and categorical variables.
#
# Multivariate analysis can also be categorized as **graphical multivariate EDA** or **non-graphical multivariate EDA**.
#
# Non-graphical multivariate EDA illustrates the relationship between two or more variables of the data through cross-tabulation or statistics.
#
# Graphical mutivariate EDA shows relatioships between three or more variables via creation of charts.
#
# Common types of multivariate graphs include:
#
# - Scatter plots: Displays relationship between two quantitative/numerical variables.The two variables, plotted along x-axis and y-axis can have their data points color coded with another qualitative variable.
# - Heat map: Graphical representation of data where values are depicted by color.
# - Bar charts: Display categorical data
# - Multivariate charts (pair plots): Type of control chart used to monitor two or more interrelated process variables
# - Line charts: Depict changes over time. Several variables whose values change over time can be plotted on a single line chart.

# %% [markdown]
# ## Exploratory Data Analysis Process
#
# The key steps executed in our Exploratory Data Analysis Process include:
#
# 1. Data Collection: Sourcing the data from different sources, verifying accuracy and storing it in the appropriate structure
# 2. Importing Python libraries
# 3. Reading Dataset: Loading dataset into the notebook as a Pandas DataFrame
# 4. Data Understanding:  Inspecting the structure of the dataset with the aim of understanding the shape of our dataset, features(variables),data types, missing values and duplicated values
# 5. Data Pre-processing: Depending on results of understanding the dataset, we can clean and wrangle our dataset
# 6. Univariate Analysis: Graphically and non-graphically
# 7. Multivariate Analysis: Graphically and non-graphically
# 8. Answering Key Questions linked to the dataset

# %% [markdown]
# ### 1. Data Collection
#
# **Source of Data**: Data is published by Central Bank of Kenya (CBK), the regulatory authority for mobile payments in Kenya. You can access the data by clicking [here](https://www.centralbank.go.ke/national-payments-system/mobile-payments/).
#
#
# **Data Accuracy**: It is collected,collated and published by CBK.
#
# The dataset is downloaded and stored as CSV file; _Mobile Payments.csv_ in my personal computer under datasets Folder.

# %% [markdown]
# ### 2. Importing Python Libraries
#
# Various Python libraries will be used to conduct EDA. They include:
#
# - pandas: Powerful tool for data manipulation and analysis
# - numpy: Package for numerical analysis
# - matplotlib: Data vislualization package
# - seaborn: Data vislualization package

# %%
#loading libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#set style for my visualizations
plt.style.use('ggplot')

# %% [markdown]
# ### 3. Reading Dataset
#
# Entails loading the `Mobile Payments.csv` dataset as a dataframe into the notebook.

# %%
#load the dataset

payments = pd.read_csv('Mobile Payments.csv')

#print payments dataset

print(payments)
# Out:
#      Year  ... Total Agent Cash in Cash Out (Value KSh billions)
# 0    2023  ...                                        666.630000
# 1    2023  ...                                        684.640000
# 2    2023  ...                                        643.760000
# 3    2023  ...                                        670.440000
# 4    2023  ...                                        615.250000
# ..    ...  ...                                               ...
# 193  2007  ...                                          1.065370
# 194  2007  ...                                          0.720102
# 195  2007  ...                                          0.483709
# 196  2007  ...                                          0.220896
# 197  2007  ...                                          0.064391
#
# [198 rows x 6 columns]

# %% [markdown]
# ### 4. Data Understanding
#
# Data understanding involves inspecting our dataframe in respect to verifying:
#
# 1. Data shape: number of rows and columns
# 2. Data columns: names of features/variables present in our dataset and data types
# 3. Check for missing values
# 4. Check for duplicated values
# 5. Statistics for numerical columns in the dataset

# %%
#Display top 5 rows
payments.head()
# Out:
#    Year  ... Total Agent Cash in Cash Out (Value KSh billions)
# 0  2023  ...                                            666.63
# 1  2023  ...                                            684.64
# 2  2023  ...                                            643.76
# 3  2023  ...                                            670.44
# 4  2023  ...                                            615.25
#
# [5 rows x 6 columns]

# %%
#Display bottom 5 rows
payments.tail()
# Out:
#      Year  ... Total Agent Cash in Cash Out (Value KSh billions)
# 193  2007  ...                                          1.065370
# 194  2007  ...                                          0.720102
# 195  2007  ...                                          0.483709
# 196  2007  ...                                          0.220896
# 197  2007  ...                                          0.064391
#
# [5 rows x 6 columns]

# %%
# Data shape: number of rows and columns

payments.shape

print(f"The number of rows is {payments.shape[0]}, and the number of columns is {payments.shape[1]}")
# Out:
# The number of rows is 198, and the number of columns is 6

# %% [markdown]
# The dataset contains **198 rows** and **6 columns**

# %%
# Inspecting the dataset

payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 6 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Year                                               198 non-null    int64
#  1   Month                                              198 non-null    object
#  2   Active Agents                                      198 non-null    int64
#  3   Total Registered Mobile Money Accounts (Millions)  198 non-null    float64
#  4   Total Agent Cash in Cash Out (Volume Million)      198 non-null    float64
#  5   Total Agent Cash in Cash Out (Value KSh billions)  198 non-null    float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 9.4+ KB

# %% [markdown]
# Based on the output of inspecting the dataset:
#
# -  There are no missing values
# -  Year column's data type is integer. The correct data type for the column should be datetime
# -  Month column's data type is recognized as string object. It will also be transformed to datetime when conducting data pre-processing
# -  Column names are too long and do not conform to best practices of naming variables. They can be renamed to shorter meaningful variable names.

# %%
#ascertain missing values

missing_values = payments.isnull().sum()

missing_values
# Out:
# Year                                                 0
# Month                                                0
# Active Agents                                        0
# Total Registered Mobile Money Accounts (Millions)    0
# Total Agent Cash in Cash Out (Volume Million)        0
# Total Agent Cash in Cash Out (Value KSh billions)    0
# dtype: int64

# %%
# Check for duplicates
duplicates_n = payments.duplicated().sum()
duplicates_n

print(f"number of duplicate values: {duplicates_n}")
# Out:
# number of duplicate values: 0

# %%
#check column names

print(payments.columns)
# Out:
# Index(['Year', 'Month', 'Active Agents',
#        'Total Registered Mobile Money Accounts (Millions)',
#        'Total Agent Cash in Cash Out (Volume Million)',
#        'Total Agent Cash in Cash Out (Value KSh billions)'],
#       dtype='object')

# %%
#check data types of columns
print(payments.dtypes)
# Out:
# Year                                                   int64
# Month                                                 object
# Active Agents                                          int64
# Total Registered Mobile Money Accounts (Millions)    float64
# Total Agent Cash in Cash Out (Volume Million)        float64
# Total Agent Cash in Cash Out (Value KSh billions)    float64
# dtype: object

# %%
#statistics for numerical columns


payments.describe().T
# Out:
#                                                    count  ...        max
# Year                                               198.0  ...    2023.00
# Active Agents                                      198.0  ...  334726.00
# Total Registered Mobile Money Accounts (Millions)  198.0  ...      77.55
# Total Agent Cash in Cash Out (Volume Million)      198.0  ...     208.61
# Total Agent Cash in Cash Out (Value KSh billions)  198.0  ...     722.52
#
# [5 rows x 8 columns]

# %% [markdown]
# **Summary Statistics Insights**
#
# The `describe()` applied to `payments` dataset outputs different statistical measures of the variables in the dataset.
#
# Later on, we will analyze individual variables statistics when conducting non-graphical univariate analysis.
#
# Based on the output of summary statistics of the dataset:
#
# a) **_Active Agents_**
#
# -  Minimum number of Active Agents was 307
# -  Maximum number of Active Agents was 334,726
# -  Average number of Active Agents was **141,792**
#
# b) **Total Registered Mobile Money Accounts (Millions)**
#
# -  Average number of registered mobile money accounts was: **33 million**
# -  Minimum number of registered mobile money accounts was: 2,092
# -  Maximum number of registered mobile money accounts was: 77.55 million
#
# c) **Total Agent Cash in Cash Out (Value KSh billions)**
#
# - Average value of Total Mobile Money Transactions(deposits and withdrawals): **260.61 Billion**
# - Minimum value of Total Mobile Money Transactions(deposits and withdrawals): 0.064 Billion
# - Maximum value of Total Mobile Money Transactions(deposits and withdrawals): 722.52 Billion

# %% [markdown]
# ### 5. Data Pre-processing
#
# It involves cleaning and transforming our raw dataset to an appropriate format suitable for analysis.
#
# The main objective of data pre-processing involves cleaning, formating, and transforming the data into a structured and well-organized format that will improve the output of the data analysis process.
#
#
# Key data pre-processing actions that will be undertaken:
#
# - Changing Year column data type to datetime
# - Change Month column's data type to datetime
# - Merge Year and Month columns to form one new column; **Date** Column
# - Drop Year and Month column
# - Renaming four columns: Column names are too long and do not conform to best practices of naming variables. They can be renamed to shorter meaningful variable names

# %%
# Let's make a copy of payments dataset. 

payments_df = payments.copy()

payments_df.head()
# Out:
#    Year  ... Total Agent Cash in Cash Out (Value KSh billions)
# 0  2023  ...                                            666.63
# 1  2023  ...                                            684.64
# 2  2023  ...                                            643.76
# 3  2023  ...                                            670.44
# 4  2023  ...                                            615.25
#
# [5 rows x 6 columns]

# %%
# Create date column by Merging Year and Month column

payments_df['Date'] = pd.to_datetime(payments_df['Year'].astype(str) + '-' + payments_df['Month'])

payments_df.head()
# Out:
#    Year   Month  ...  Total Agent Cash in Cash Out (Value KSh billions)       Date
# 0  2023  August  ...                                             666.63 2023-08-01
# 1  2023    July  ...                                             684.64 2023-07-01
# 2  2023    June  ...                                             643.76 2023-06-01
# 3  2023     May  ...                                             670.44 2023-05-01
# 4  2023   April  ...                                             615.25 2023-04-01
#
# [5 rows x 7 columns]

# %%
#Drop Year and Month Columns from payments_df

payments_df = payments_df.drop(["Year", "Month"], axis=1)
payments_df
# Out:
#      Active Agents  ...       Date
# 0           333428  ... 2023-08-01
# 1           330912  ... 2023-07-01
# 2           328543  ... 2023-06-01
# 3           334726  ... 2023-05-01
# 4           329968  ... 2023-04-01
# ..             ...  ...        ...
# 193            681  ... 2007-07-01
# 194            527  ... 2007-06-01
# 195            447  ... 2007-05-01
# 196            362  ... 2007-04-01
# 197            307  ... 2007-03-01
#
# [198 rows x 5 columns]

# %%
# Rename the following three columns:

#Total Registered Mobile Money Accounts (Millions),Total Agent Cash in Cash Out (Volume Million) 
# and Total Agent Cash in Cash Out (Value KSh billions) 

payments_df = payments_df.rename(columns={'Total Registered Mobile Money Accounts (Millions)': 'Mobile_Money_Accounts(Millions)', 'Total Agent Cash in Cash Out (Volume Million)': 'Cash_Deposits_Withdrawal_Volume(Million)', 'Total Agent Cash in Cash Out (Value KSh billions)': 'Cash_Deposits_Withdrawal_Value(KES billions)'})

payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 5 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Active Agents                                 198 non-null    int64
#  1   Mobile_Money_Accounts(Millions)               198 non-null    float64
#  2   Cash_Deposits_Withdrawal_Volume(Million)      198 non-null    float64
#  3   Cash_Deposits_Withdrawal_Value(KES billions)  198 non-null    float64
#  4   Date                                          198 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 7.9 KB

# %%
#Rename Active Agents column to a pythonic format

payments_df = payments_df.rename(columns={'Active Agents': 'Active_Agents'})
payments_df.head()
# Out:
#    Active_Agents  ...       Date
# 0         333428  ... 2023-08-01
# 1         330912  ... 2023-07-01
# 2         328543  ... 2023-06-01
# 3         334726  ... 2023-05-01
# 4         329968  ... 2023-04-01
#
# [5 rows x 5 columns]

# %% [markdown]
# Based on the data transformation steps executed above:
#
#
# - A new column, `Date` has been added into the dataset
# - `payments_df` has five columns after transforming Year and Month columns. The original dataset,`payments` has 6 columns.
# -  Four Variable names have been renamed.

# %% [markdown]
# ### 6. Univariate Analysis
#
# Non-graphical and graphical univariate analysis will be executed on the following features(columns):
#
# a) Active_Agents
#
# b) Mobile_Money_Accounts(Millions)

# %% [markdown]
# **Non-graphical univariate analysis of Active_Agents**
#
# Simple summary statistics of this columns can be computed using `describe()`
#
# We can also compute the range and percentage change.

# %%
#summary statistics of Active_Agents

Active_Agents_stats = payments_df["Active_Agents"].describe()
Active_Agents_stats
# Out:
# count       198.000000
# mean     141792.828283
# std      104703.538988
# min         307.000000
# 25%       38726.000000
# 50%      130748.000000
# 75%      223003.000000
# max      334726.000000
# Name: Active_Agents, dtype: float64

# %% [markdown]
# Average number of Active_Agents is **141,792**. It is simillar to what we got earlier when we used the `describe()` on the entire dataset.

# %%
#range of Active_Agents

range_active = Active_Agents_stats[7] - Active_Agents_stats[3]

print(f"The range of Active_Agents is: {range_active}")
# Out:
# The range of Active_Agents is: 334419.0

# %%
#Percentage increase rate of Active_agents

Active_agents_perc = round((range_active / Active_Agents_stats[3]) * 100, 1)

print(f"The percentage increase in number of Active agents is: {Active_agents_perc:.2f}%")
# Out:
# The percentage increase in number of Active agents is: 108931.30%

# %% [markdown]
# **Key Insights**
#
# Based on computing range and percentage change, it is accurate to conclude that:
#
# Difference between maximum and minimum number of Active agents who faciliate cash deposit and withdrawal was **334,419**.
#
# This means in a period of 17 years (January 2007 to August 2023), the number of active agents in Kenya increased by 334,419.
#
# The above increase in number of active agents represents a percentage increase of **108,931.30%**

# %% [markdown]
# **Graphical Univariate Analysis of Active_Agents**
#
# Visual analysis of Active_Agents will involve exploring the feature's distribution, key characteristics and patterns.
#
# Graphs to be used include:
#
# -  Histogram
# -  Boxplot

# %%
# Plot histogram of Active_Agents column
plt.figure(figsize=(10,8))
plt.hist(payments_df['Active_Agents'], bins=10, color='blue', edgecolor='k')
plt.xlabel('Active Agents')
plt.ylabel('Frequency')
plt.title('Histogram of Active Agents')
plt.show()

# %% [markdown]
# Based on the histogram illustrated, Active_Agent does not have a normal distribution.
#
# The shape of the distribution is positively skewed, where majority of high value data points are located on the right side of the histogram.
#
# The mean is usually higher than the median for a positively skewed distribution.

# %%
# Plot boxplot of Active_Agents column

plt.figure(figsize=(8,6))
sns.boxplot(x=payments_df['Active_Agents'])
plt.xlabel('Active Agents')
plt.title('Boxplot of Active Agents')
plt.show()

# %% [markdown]
# The boxplot alighns with statistical values derived from computing descriptive statistsics. There are no outliers.

# %% [markdown]
# **Non-graphical Univariate Analysis of Mobile_Money_Accounts(Millions)**
#
# We will look at simple summary statistics and the range.

# %%
#summary statistics of Mobile_Money_Accounts

Mobile_Money_Accounts_stats = payments_df["Mobile_Money_Accounts(Millions)"].describe()
Mobile_Money_Accounts_stats
# Out:
# count    198.000000
# mean      33.341681
# std       22.899713
# min        0.020992
# 25%       17.798950
# 50%       26.483650
# 75%       53.464200
# max       77.550000
# Name: Mobile_Money_Accounts(Millions), dtype: float64

# %% [markdown]
# Average number of Mobile_Money_Accounts(Millions) is **33.34 million**. It is simillar to what we got earlier when we used the `describe()` on the entire dataset.

# %%
#range of Mobile_Money_Accounts

range_Mobile_Money_Accounts = Mobile_Money_Accounts_stats[7] - Mobile_Money_Accounts_stats[3]

print(f"The range of Mobile_Money_Accounts is: {range_Mobile_Money_Accounts:.2f} million")
# Out:
# The range of Mobile_Money_Accounts is: 77.53 million

# %%
#Percentage increase rate of Mobile_Money_Accounts

Mobile_Money_Accounts_perc = round((range_Mobile_Money_Accounts / Mobile_Money_Accounts_stats[3]) * 100, 1)

print(f"The percentage increase in number of Registered Mobile Money Accounts is: {Mobile_Money_Accounts_perc:.2f}%")
# Out:
# The percentage increase in number of Registered Mobile Money Accounts is: 369326.40%

# %% [markdown]
# **Key Insights**
#
# Key insights derived from non-graphical analysis of Mobile Money Accounts include:
#
# Difference between maximum and minimum number of Registered Mobile Money Accounts  was **77.53 million**.
#
# This means in a period of 17 years (January 2007 to August 2023), the number of registered mobile money accounts in Kenya increased by 77.53 million.
#
# The above increase in number of registered mobile money accounts represents a percentage increase of **369,326.40%**

# %% [markdown]
# **Graphical Univariate Analysis of Mobile_Money_Accounts(Millions)**
#
# Two visuals, a boxplot and a histogram will be plotted to explore the distribution and patterns of Mobile_Money_Accounts(Millions)

# %%
# Plot histogram of Mobile_Money_Accounts(Millions)

plt.figure(figsize=(10,8))
plt.hist(payments_df['Mobile_Money_Accounts(Millions)'], bins=10, color='blue', edgecolor='k')
plt.xlabel('Mobile Money Accounts (Millions)')
plt.ylabel('Frequency')
plt.title('Histogram of Mobile Money Accounts')
plt.show()

# %%
# Calculate skewness
skewness = round(payments_df['Mobile_Money_Accounts(Millions)'].skew(),2)

# Print the skewness
print('Skewness:', skewness)
# Out:
# Skewness: 0.43

# %% [markdown]
# The histogram is moderately positively skewed, depicting that Mobile_Money_Accounts is moderately positively skewed.
#
# To ascertain the variable's skewness, skewness value of Mobile_Money_Accounts was computed, yielding a positive value of **0.43**

# %%
# Plot boxplot of Mobile_Money_Accounts(Millions)

plt.figure(figsize=(10,8))
sns.boxplot(x=payments_df['Mobile_Money_Accounts(Millions)'])
plt.xlabel('Mobile Money Accounts (Millions)')
plt.title('Boxplot of Mobile Money Accounts')
plt.show()

# %% [markdown]
# Based on the output of the boxplot, the median is close to the lower end of the boxplot, thus confirming that the distribution of Mobile Money Accounts is positively skewed. Majority of data points lie above the median.
#
# There are no outliers.

# %% [markdown]
# ### 7. Multivariate Analysis
#
# Multiple variables will be analyzed graphically and non-graphically. They include:
#
# 1. Active_Agents
# 2. Mobile_Money_Accounts(Millions)
# 3. Cash_Deposits_Withdrawal_Volume(Millions)
# 4. Cash_Deposits_Withdrawal_Value(KES billions)

# %% [markdown]
# **Graphical Bivariate Analysis of Active_Agents and Cash_Deposits_Withdrawal_Volume(Millions)**
#
#
# We want to analyze the relationship between the number of active agents and volume of mobile money transactions. The best graph to illustrate the relationship is a scatter plot.

# %%
# Plot scatter plot of Active_Agents and Cash_Deposits_Withdrawal_Volume(Millions)

plt.figure(figsize=(8,6))
sns.scatterplot(x=payments_df['Active_Agents'], y=payments_df['Cash_Deposits_Withdrawal_Volume(Million)'])
plt.xlabel('Active_Agents')
plt.ylabel('Cash Deposits/Withdrawal Volume(Millions)')
plt.title('Scatter Plot of Active Agents and Cash Deposits/Withdrawal Volume')
plt.show()

# %% [markdown]
# Based on the output of the plot, the data points display an upward-sloping pattern from left to right, thus indicating a positive linear relationship between Active Agents and Cash_Deposits_Withdrawal_Volume.
#
# This means increase in the number of Active Agents leads to an increase in Cash_Deposits_Withdrawal_Volume.
#
# To ascertain the strength and type of correlation between the two variables, we can compute correlation coefficient.

# %% [markdown]
# **Non-Graphical Bivariate Analysis of Active_Agents and Cash_Deposits_Withdrawal_Volume(Millions)**
#
# **Correlation Coefficient**
#
# A non-graphical measure, corelation coefficient will be calculated.
#
# The correlation coefficient is a statistical measure used to quantify the strength and direction of a linear relationship between two variables. It provides valuable insights into how two variables are related.

# %%
# Calculate the correlation coefficient

correlation_coefficient = payments_df['Active_Agents'].corr(payments_df['Cash_Deposits_Withdrawal_Volume(Million)'])

print(f"The Correlation Coefficient between Active Agents and Cash Deposits/Withdrawal Volume is: {correlation_coefficient:.2f}")
# Out:
# The Correlation Coefficient between Active Agents and Cash Deposits/Withdrawal Volume is: 0.99

# %% [markdown]
# **Correlation Coefficient Result**
#
# Active Agents and Cash_Deposits_Withdrawal_Volume are strongly positively correlated. Their correlation coefficient is **0.99**. This means that when the number of Active Agents increases, the volume of transctions also increases.

# %% [markdown]
# **Graphical Bivariate Analysis of Mobile_Money_Accounts(Millions) and Cash_Deposits_Withdrawal_Value(KES billions)**
#
# We can also investigate if the relationship between registered Mobile Money Accounts and Cash_Deposits_Withdrawal_Value(KES billions) is linear.

# %%
# Plot scatter plot of Mobile_Money_Accounts(Millions) and Cash_Deposits_Withdrawal_Value(KES billions)

plt.figure(figsize=(8,6))
sns.scatterplot(x=payments_df['Mobile_Money_Accounts(Millions)'], y=payments_df['Cash_Deposits_Withdrawal_Value(KES billions)'])
plt.xlabel('Mobile Money Accounts(Millions)')
plt.ylabel('Cash Deposits/Withdrawal Value(KES billions)')
plt.title('Scatter Plot of Mobile Money Accounts and Cash Deposits/Withdrawal Value')
plt.show()

# %% [markdown]
# Based on the output of the scatter plot above, the data points display an upward-sloping pattern from left to right(though most values are concetrated on the lower end of te curve), thus indicating a positive linear relationship between Mobile Money Accounts(Millions) and Cash_Deposits_Withdrawal_Value(KES billions).
#
# This means increase in the number of  Mobile Money Accounts leads to an increase in monetary value of Cash Deposits/Withdrawal.
#
# Let's verify the type and strength of the relationship between the two variables by computing correlation coefficient.

# %%
# Calculate the correlation coefficient between Mobile Money Accounts and Cash Deposits/Withdrawal Value

correlation_coefficient_2 = payments_df['Mobile_Money_Accounts(Millions)'].corr(payments_df['Cash_Deposits_Withdrawal_Value(KES billions)'])

print(f"The Correlation Coefficient between Mobile Money Accounts and Cash Deposits/Withdrawal Value is: {correlation_coefficient_2:.2f}")
# Out:
# The Correlation Coefficient between Mobile Money Accounts and Cash Deposits/Withdrawal Value is: 0.98

# %% [markdown]
# **Correlation Coefficient Result**
#
# Mobile Money Accounts and Cash_Deposits_Withdrawal_Value(KES billions) are strongly positively correlated. Their correlation coefficient is **0.98**.
#
# This means that when the number of registered Mobile Money Accounts  increases, the monetary value of mobile money tranactions increases.

# %% [markdown]
# **Correlation Matrix**
#
# A correlation matrix enables us understand the linear relationship between variables in the dataset. The correlation between variables is determined by the correlation coefficeint.
#
# A correlation matrix quantifies the strength and direction of the relationship, ranging from -1 to 1 whereby:
#
# - A value of 1 represents a **perfect positive correlation**, depicting that as one variable increases, the other variable also increases in a linear format.
# - A value of -1 represents a **perfect negative correlation**, indicating that as one variable increases, the other variable decreases in a linear format.
# - A value of 0 indicates no linear correlation between the two variables.
#
# We can create a correlation matrix of our dataset and visualize the results using a heatmap.

# %%
# Create correlation matrix

correlation_matrix = payments_df.corr()

correlation_matrix
# Out:
#                                               Active_Agents  ...  Cash_Deposits_Withdrawal_Value(KES billions)
# Active_Agents                                      1.000000  ...                                      0.981596
# Mobile_Money_Accounts(Millions)                    0.986675  ...                                      0.976455
# Cash_Deposits_Withdrawal_Volume(Million)           0.989126  ...                                      0.969390
# Cash_Deposits_Withdrawal_Value(KES billions)       0.981596  ...                                      1.000000
#
# [4 rows x 4 columns]

# %%
# Visualize correlation matrix using a heatmap

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **Correlation Matrix Results**
#
# From the heatmap we can infer the following:
#
# 1. Mobile Money Accounts and Active_Agents are strongly positively correlated. Their correlation coefficient is **0.99**.
# 2. Mobile Money Accounts and Cash_Deposits_Withdrawal_Value(KES billions) are strongly positively correlated. Their correlation coefficient is **0.98**.
# 3. Active Agents and Cash_Deposits_Withdrawal_Volume are strongly positively correlated. Their correlation coefficient is **0.99**.
# 4. Cash_Deposits_Withdrawal_Volume and Number of Registered Mobile Market Accounts are positively correlated.Their correlation coefficient is **0.97**.
# 5. Cash_Deposits_Withdrawal_Volume(Million) and Cash_Deposits_Withdrawal_Value(KES billions) are positively correlated.Their correlation coefficient is **0.97**.

# %% [markdown]
# ### 8. Answering Key Questions Linked to the Dataset
#
# The core part of the EDA process has been executed.
#
# Several sigificant questions related to the dataset can be answered. Key questions that can be answered include:
#
# - Compute the change in volume of mobile money transactions(cash deposits and cash withdrawals) that have occured from 2007 to 2023
#
#
# - Compute the percentage change in volume of mobile money transactions that have occured from 2007 to 2023
#
#
# - Compute the change in monetary value of mobile money transactions(cash deposits and cash withdrawals) that have occured from 2007 to 2023
#
#
# - Compute the percentage change monetary value of mobile money transactions that have occured from 2007 to 2023

# %%
#summary stats of Cash_Deposits_Withdrawal_Volume(Millions)

Cash_Deposit_Withdrawal_stats = payments_df['Cash_Deposits_Withdrawal_Volume(Million)'].describe()

Cash_Deposit_Withdrawal_stats
# Out:
# count    198.000000
# mean      94.448061
# std       64.829920
# min        0.021714
# 25%       33.384000
# 50%       90.508150
# 75%      151.677000
# max      208.610000
# Name: Cash_Deposits_Withdrawal_Volume(Million), dtype: float64

# %%
#range of Cash_Deposit_Withdrawal_Volume

range_cash_deposit_withdrawal_volume = Cash_Deposit_Withdrawal_stats[7] - Cash_Deposit_Withdrawal_stats[3]

print(f"The range of Cash Deposit/Withdrawal Volume is: {range_cash_deposit_withdrawal_volume:.2f} million")
# Out:
# The range of Cash Deposit/Withdrawal Volume is: 208.59 million

# %%
#Percentage increase of Cash_Deposit_Withdrawal_Volume

Cash_Deposit_Withdrawal_perc = round((range_cash_deposit_withdrawal_volume / Cash_Deposit_Withdrawal_stats[3]) * 100, 1)

print(f"The percentage increase in Cash Deposit/Withdrawal Volume is: {Cash_Deposit_Withdrawal_perc:.2f}%")
# Out:
# The percentage increase in Cash Deposit/Withdrawal Volume is: 960616.60%

# %% [markdown]
# **Quiz 1: Change in Volume of Mobile Money Transactions**
#
# Change in volume of mobile money transactions(cash deposits and cash withdrawals) that have occured from 2007 to 2023 was **208.59 million**.
#
# This means in a period of 17 years (January 2007 to August 2023), the volume of mobile money transactions in Kenya increased by 208.59 million.

# %% [markdown]
# **Quiz 2: Percentage Change in Volume of Mobile Money Transactions**
#
# Percentage increase in volume of mobile money transactions that have occured in Kenya from 2007 to 2023 is **96,016.60%**.

# %%
#summary stats of Cash_Deposits_Withdrawal_Value(KES billions)

Cash_transactions_value_stats = payments_df['Cash_Deposits_Withdrawal_Value(KES billions)'].describe()

Cash_transactions_value_stats
# Out:
# count    198.000000
# mean     260.609580
# std      202.990415
# min        0.064391
# 25%       89.908375
# 50%      230.994000
# 75%      363.244500
# max      722.520000
# Name: Cash_Deposits_Withdrawal_Value(KES billions), dtype: float64

# %%
#range of Cash_Deposit_Withdrawal_Value(KES billions)

range_cash_transactions_value = Cash_transactions_value_stats[7] - Cash_transactions_value_stats[3]

print(f"The range of Cash Deposit/Withdrwal Monetary Value is: KES {range_cash_transactions_value:.2f} billion")
# Out:
# The range of Cash Deposit/Withdrwal Monetary Value is: KES 722.46 billion

# %%
#Percentage increase of Cash_Deposit_Withdrawal_Value(KES billions)

Cash_trasactions_value_perc = round((range_cash_transactions_value / Cash_transactions_value_stats[3]) * 100, 1)

print(f"The percentage increase in Cash Deposit/Withdrawal Monetary Value is: {Cash_trasactions_value_perc:.2f}%")
# Out:
# The percentage increase in Cash Deposit/Withdrawal Monetary Value is: 1121991.00%

# %% [markdown]
# **Quiz 3: Change in Monetary Value of Mobile Money Transactions**
#
# Change in monetary value of mobile money transactions(cash deposits and cash withdrawals) that have occured from 2007 to 2023 was **KES 722.46 billion**.
#
# This means in a period of 17 years (January 2007 to August 2023), the monetary value of mobile money transactions in Kenya increased by KES 722.46 billion.
#
# _**Please note**_: KES represents the currency of Kenya.

# %% [markdown]
# **Quiz 4: Percentage Change in Monetary Value of Mobile Money Transactions**
#
# Percentage increase in monetary value of mobile money transactions that have occured in Kenya from 2007 to 2023 is **1,121,991%**

# %% [markdown]
# ## Conclusion
#
# Exploratory Data Analysis process is the cornerstone for any data analysis project. It facilitates understanding of the data structure, identification of trends, patterns and outliers. EDA can be performed using graphical or non-graphical techniques.
#
# **Growth of Mobile Payments in Kenya**
#
# Based on the EDA performed on mobile payments data, several insights regarding the growth of mobile payments in Kenya were obtained.
#
# They include:
#
# _Note: The growth of mobile money payments timeline is 17 years(January 2007 to August 2023)_
#
#
#
# 1.  The number of active agents in Kenya increased by **334,419**. This represents a percentage increase of **108,931.30%**.
# 2.  The number of registered mobile money accounts in Kenya increased by **77.53 Million**. This represents a percentage increase of **369,326.40%**.
# 3. The volume of mobile money transactions in Kenya increased by **208.59 million**. This represents percentage increase **96,016.60%**.
# 4. The monetary value of mobile money transactions in Kenya increased by **KES 722.46 billion**. This represents a percentage increase of **1.12 Million%**.
